# %% [markdown]
# # Assignment 2 Report

# %% [markdown]
# This is an outline for your report to ease the amount of work required to create your report. Jupyter notebook supports markdown, and I recommend you to check out this [cheat sheet](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet). If you are not familiar with markdown.
#
# Before delivery, **remember to convert this file to PDF**. You can do it in two ways:
# 1. Print the webpage (ctrl+P or cmd+P)
# 2. Export with latex. This is somewhat more difficult, but you'll get somehwat of a "prettier" PDF. Go to File -> Download as -> PDF via LaTeX. You might have to install nbconvert and pandoc through conda; `conda install nbconvert pandoc`.

# %% [markdown]
# # Task 1

# %% [markdown]
# ## task 1a)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Task 2

# %% [markdown]
# ## Task 2a)
# ![image.png](attachment:image-2.png)

# %% [markdown]
# ## Task 2c)
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Task 2d)
# number of params = num_weights + num_biases
#                  = 785X64+64X10+(785+64+10) = 51739

# %% [markdown]
# # Task 3

# %% [markdown]
# The convergence speed increases with each addition from the tricks of the trade suggestions. The one with all the tricks stopped after 14 epochs, so it is a bit difficult to analyse, but it increased it's validation accuracy fast and seemed to level out around where it stopped. The validation loss for the networks with the most tricks seem to stop decreasing quickly which could be a sign that the network is overfitting. The network with every trick even has a rising validation loss at the end which is a definite sign of overfitting. The accuracy for this network also flattens out which indicates overfitting aswell. The networks with the most tricks seem to end up with the highest final accuracy and validation loss, so they seem to be helpful additions.
# ![image.png](attachment:image.png)

# %% [markdown]
# # Task 4

# %% [markdown]
# ## Task 4a)
# The end accuracy is lower than for 64 neurons. The early stopping kicks in much later, so it converges slower. The network doesn't have the same complexity as with 64 neurons which seems to be a worse fit for the classification problem. The validation loss seems to flatten out which could indicate overfitting
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Task 4b)
# The accuracy varies much more than with 64 neurons as there are more weights that have to be set and explored. The early stopping kicks in much later, so it converges slower. The cross entropy loss is also much higher with 128 neurons. The accuracy converges on a lower number than for 64 neurons.
# ![](task4a128_train_loss.png)

# %% [markdown]
# ## Task 4d)
# FILL IN ANSWER

# %% [markdown]
# ## Task 4e)
# FILL IN ANSWER
