# %% [markdown]
# # Assignment 3 Report Group 114

# %% [markdown]
# This is an outline for your report to ease the amount of work required to create your report. Jupyter notebook supports markdown, and I recommend you to check out this [cheat sheet](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet). If you are not familiar with markdown.
#
# Before delivery, **remember to convert this file to PDF**. You can do it in two ways:
# 1. Print the webpage (ctrl+P or cmd+P)
# 2. Export with latex. This is somewhat more difficult, but you'll get somehwat of a "prettier" PDF. Go to File -> Download as -> PDF via LaTeX. You might have to install nbconvert and pandoc through conda; `conda install nbconvert pandoc`.

# %% [markdown]
# # Task 1

# %% [markdown]
# ## task 1a)
# ![image.png](attachment:image-2.png)

# %% [markdown]
# ## task 1b)
#
# It's the max pooling layer that makes the CNN invariant to small translational shifts in the input image, as it works as a "summary" of a group of values.
#
# ![image.png](attachment:image.png)
#
# ![image.png](attachment:image-2.png)
#
# ![image.png](attachment:image-3.png)
# ![image.png](attachment:image-4.png)

# %% [markdown]
# # Task 2
#
# ### Task 2a)
# ![image.png](attachment:image.png)
# ### Task 2b)
# ![image.png](attachment:image-2.png)

# %% [markdown]
# # Task 3

# %% [markdown]
# ### Task 3a)
# ![image.png](attachment:image-6.png)
# ![image.png](attachment:image-3.png)
# ### Task 3b)
# ![image.png](attachment:image-2.png)
# ![image.png](attachment:image-4.png)
#
# ### Task 3c)
# For me the batch normalization was useful to make the network train faster, and the dropout increased performance slightly. Increasing the depth of the network while using the (conv-batchnorm-relu)x2-maxpool2d gave a big improvement over the network in table 1. The depth of the network gives it the complexity needed to generalize well to the classes. Another improvement was made after slowly increasing the amount of filters per layer.Decreasing the size of the filter towards the end of the feature extractor when the size of the input was reduced by two maxpools increased the performance as it allowed the neural net to more precisely identify features in the smaller inputs. Datamodification using rotation and horizontal/vertical flipping did only worsen the performance of the validation accuracy and was thus omitted from the model in 3a). The rotation could have made the dataset worse as it fills the empty pixels with a zero value which could be affecting the weights in unexpected ways.
# ### Task 3d)
# The method that seemed to give the most significant improvement was to increase the depth of the feature extractor and the classifier. The below figure was from the previous best before increasing depth. It can be seen that the validation accuracy is below 0.8 for all time and the validation and training loss is higher than for the deeper model.
# ![image.png](attachment:image-5.png)
# ### Task 3e)
# See figures task 3b). The final test accuracy was 0.787 but for the previous check it was above 0.8.
# ### Task 3f)
# The validation loss spikes at the last check which could be a sign that the model is overfitting although it may also be a random spike. The validation loss curve seems to stop improving towards the end of the training while the training accuracy keeps growing which also could be a sign of overfitting.

# %% [markdown]
# # Task 4

# %% [markdown]
# ## Task 4a)
#
# ![image.png](attachment:image-3.png)
# ![image.png](attachment:image.png)
#
# The final test accuracy was 0.9028.
# Using:
#
# Learningrate = 5e-4
#
# batch size = 32
#
# transforms.Resize(112,112)
#
# epochs = 5
#
# early_stop_count = 4
